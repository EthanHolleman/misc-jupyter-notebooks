# %%
from Bio import Entrez
import pandas as pd
import time

# %%
Entrez.email = "etholleman@ucdavis.edu"

# %% [markdown]
# BLAST tabular output headers

# %%
COL_NAMES = (
    "qseqid",
    "sseqid",
    "pident",
    "length",
    "mismatch",
    "gapopen",
    "qstart",
    "qend",
    "sstart",
    "send",
    "evalue",
    "bitscore",
)

# %% [markdown]
# Outside of this notebook I BLASTed all sequences (from `all_text.fas` file) using BLASTn and then downloaded the
# results of all alignments.

# %%
latest_download = '2022-02-11_751722_138389_data (1)/0JX3GD7A016-Alignment-HitTable.csv'
latest_df = pd.read_csv(latest_download, header=None)
latest_df.columns = COL_NAMES

# %%
latest_df.head()
# Out:
#                                               qseqid      sseqid  pident  \
# 0  pFC8_tac_T1T2_Vrmix#3_10_pFC8tac_tac_promoter_...  CP046087.1   100.0
# 1  pFC8_tac_T1T2_Vrmix#3_10_pFC8tac_tac_promoter_...  CP036485.1   100.0
# 2  pFC8_tac_T1T2_Vrmix#3_10_pFC8tac_tac_promoter_...  CP033477.1   100.0
# 3  pFC8_tac_T1T2_Vrmix#3_10_pFC8tac_tac_promoter_...  CP033494.1   100.0
# 4  pFC8_tac_T1T2_Vrmix#3_10_pFC8tac_tac_promoter_...  CP029160.1   100.0
#
#    length  mismatch  gapopen  qstart  qend   sstart     send  evalue  bitscore
# 0     674         0        0      42   715   910768   910095     0.0    1245.0
# 1     674         0        0      42   715   878955   878282     0.0    1245.0
# 2     674         0        0      42   715   872028   871355     0.0    1245.0
# 3     674         0        0      42   715   860629   859956     0.0    1245.0
# 4     674         0        0      42   715  9954961  9954288     0.0    1245.0

# %% [markdown]
# Get the best alignment for read read by percent identity, exclude any alignments that are less that 200 bp

# %%
def parse_by_read(df, min_align_length=200):
    reads = list(set(df['qseqid']))
    rep_aligns = []
    for r in reads:
        rows = df.loc[df['qseqid'] == r]
        rows = rows.loc[rows['length'] > min_align_length]
        best_pident = rows['pident'].idxmax()
        rep_aligns.append(rows.loc[best_pident])
    return pd.DataFrame(rep_aligns)

align = parse_by_read(latest_df)

# %%
align.head()
# Out:
#                                                  qseqid      sseqid  pident  \
# 1002  pFC8_tac_T1T2_Vrmix#3_3_pFC8tac_tac_promoter_P...  MF084286.1   100.0
# 1113  pFC8_tac_T1T2_Vrmix#3_4_pFC8tac_tac_promoter_P...  CP046087.1   100.0
# 318   pFC8_tac_T1T2_Vrmix#3_14_pFC8tac_tac_promoter_...  MF084286.1   100.0
# 100   pFC8_tac_T1T2_Vrmix#3_11_pFC8tac_tac_promoter_...  MF084286.1   100.0
# 1225  pFC8_tac_T1T2_Vrmix#3_5_pFC8tac_tac_promoter_P...  MF084286.1   100.0
#
#       length  mismatch  gapopen  qstart  qend  sstart    send         evalue  \
# 1002     256         0        0      80   335   10729   10474  1.280000e-128
# 1113     674         0        0      44   717  910768  910095   0.000000e+00
# 318      256         0        0      86   341   10729   10474  1.430000e-128
# 100      256         0        0      82   337   10729   10474  1.430000e-128
# 1225     256         0        0      82   337   10729   10474  1.280000e-128
#
#       bitscore
# 1002     473.0
# 1113    1245.0
# 318      473.0
# 100      473.0
# 1225     473.0

# %%
len(align['qseqid'])
# Out:
# 14

# %% [markdown]
# Use biopython to search entrez for the accessions included in BLAST results and download genbank files of those
# accessions. Extract descriptions to get human readable name for alignments.

# %%
def add_accession_description(df):
    descriptions = []
    for i, row in df.iterrows():
        print(f'Searching for {row["sseqid"]}')
        accession = Entrez.efetch(db="nucleotide", id=row['sseqid'], rettype="gb", retmode="text")
        descriptions.append(
            SeqIO.read(accession, 'gb').description
        )
        time.sleep(2)
    df['description'] = descriptions
    return df

# %%
align = add_accession_description(align)
# Out:
# Searching for MF084286.1
# Searching for CP046087.1
# Searching for MF084286.1
# Searching for MF084286.1
# Searching for MF084286.1
# Searching for CP046087.1
# Searching for CP029160.1
# Searching for NM_005244.5
# Searching for XM_005260327.2
# Searching for CP046087.1
# Searching for CP046087.1
# Searching for MF084286.1
# Searching for CP046087.1
# Searching for MF084286.1

# %%
align[['qseqid', 'description', 'pident', 'length']]
# Out:
#                                                  qseqid  \
# 1002  pFC8_tac_T1T2_Vrmix#3_3_pFC8tac_tac_promoter_P...
# 1113  pFC8_tac_T1T2_Vrmix#3_4_pFC8tac_tac_promoter_P...
# 318   pFC8_tac_T1T2_Vrmix#3_14_pFC8tac_tac_promoter_...
# 100   pFC8_tac_T1T2_Vrmix#3_11_pFC8tac_tac_promoter_...
# 1225  pFC8_tac_T1T2_Vrmix#3_5_pFC8tac_tac_promoter_P...
# 1381  pFC8_tac_T1T2_Vrmix#3_6_pFC8tac_tac_promoter_P...
# 222   pFC8_tac_T1T2_Vrmix#3_12_pFC8tac_tac_promoter_...
# 697   pFC8_tac_T1T2_Vrmix#3_23_pFC8tac_tac_promoter_...
# 810   pFC8_tac_T1T2_Vrmix#3_24_pFC8tac_tac_promoter_...
# 897   pFC8_tac_T1T2_Vrmix#3_2_pFC8tac_tac_promoter_P...
# 0     pFC8_tac_T1T2_Vrmix#3_10_pFC8tac_tac_promoter_...
# 547   pFC8_tac_T1T2_Vrmix#3_1_pFC8tac_tac_promoter_P...
# 435   pFC8_tac_T1T2_Vrmix#3_15_pFC8tac_tac_promoter_...
# 1486  pFC8_tac_T1T2_Vrmix#3_8_pFC8tac_tac_promoter_P...
#
#                                             description   pident  length
# 1002  Expression vector pYES2-Os1-HH, complete sequence  100.000     256
# 1113  Saccharomyces cerevisiae strain CEN.PK113-7D c...  100.000     674
# 318   Expression vector pYES2-Os1-HH, complete sequence  100.000     256
# 100   Expression vector pYES2-Os1-HH, complete sequence  100.000     256
# 1225  Expression vector pYES2-Os1-HH, complete sequence  100.000     256
# 1381  Saccharomyces cerevisiae strain CEN.PK113-7D c...  100.000     674
# 222   Saccharomyces cerevisiae strain SY14 chromosom...  100.000     244
# 697   Homo sapiens EYA transcriptional coactivator a...   99.897     967
# 810   PREDICTED: Homo sapiens EYA transcriptional co...   99.686     954
# 897   Saccharomyces cerevisiae strain CEN.PK113-7D c...  100.000     674
# 0     Saccharomyces cerevisiae strain CEN.PK113-7D c...  100.000     674
# 547   Expression vector pYES2-Os1-HH, complete sequence  100.000     256
# 435   Saccharomyces cerevisiae strain CEN.PK113-7D c...  100.000     674
# 1486  Expression vector pYES2-Os1-HH, complete sequence  100.000     256

# %% [markdown]
# Reads show very strong alignment to yeast genes, and many expression vectors; we do not have yeast in the lab and are not using any of these expression vectors. Further the primer used for these sequencing reactions would
# not be capable of binding to any of these sequences.

# %%
align.to_csv('aligned-reads-blast.tsv', sep='\t', index=None)
